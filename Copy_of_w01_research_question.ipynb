# %% [markdown]
# <a href="https://colab.research.google.com/github/MaiAlhusseini/FlyRank_Intern_repo/blob/main/Copy_of_w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MaiAlhusseini/FlyRank_Intern_repo/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Lane 2: Refresh / Content Opportunity Scoring is what I chose
# I chose Lane 2: Refresh / Content Opportunity Scoring because it combines machine learning with a real-world business problem. It gives me the opportunity to build an end-to-end solution, from data analysis and feature engineering to model development and evaluation, while producing actionable recommendations. I also like that the results are explainable through ranked priorities and reason codes, making the project both technically challenging and practically valuable.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# My work improves the decision of which content pages should be prioritized for refresh, expansion, monitoring, or protection. The primary users are the SEO and content teams, who will use the ranked recommendations to allocate their time and resources effectively. A wrong recommendation could lead to wasting effort on low-impact pages or overlooking high-potential pages, resulting in missed traffic opportunities and reduced overall content performance.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# I'm sorry but the dataset isn't working for me I don't know where is the problem actually

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# My work provides decision support by identifying pages that are likely good candidates for refresh, expansion, protection, or monitoring based on historical content and performance signals. It identifies patterns and prioritizes opportunities, but it does not prove that refreshing a page will improve rankings or traffic. It also does not predict Google's algorithm or establish causal relationships between content changes and search performance.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
